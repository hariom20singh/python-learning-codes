# %% [markdown]
# <a href="https://colab.research.google.com/github/GOVINDFROMINDIA/python-learning-codes/blob/main/COSnSIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy   as np
r = list(range(0,361,15))
x = [i*(np.pi/180) for i in r]
plt.plot(r,np.sin(x))
plt.plot(r,np.cos(x))
plt.title("BASIC TRIGNOMETRY")
plt.xlabel("ANGLES")
plt.ylabel("VALUES")

plt.show()
