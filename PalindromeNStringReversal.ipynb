# %% [markdown]
# <a href="https://colab.research.google.com/github/GOVINDFROMINDIA/python-learning-codes/blob/main/PalindromeNStringReversal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= str(input("ENTER THE WORD:   "))

if x == x[::-1] :
  print(x, "is a palindrome")
else:
  print(x[::-1], " is the reverse")
# Out:
# ENTER THE WORD:   malayalam
# malayalam is a palindrome
